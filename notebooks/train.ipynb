# %% [markdown]
# # LSTM Digital Twin — Three-Phase Induction Motor
#
# Trains the LSTM digital twin on the Simulink export. All the pipeline logic lives in
# [`digital_twin_lstm.py`](../digital_twin_lstm.py); this notebook is a thin runner so the
# training can also be launched from Jupyter/Colab.
#
# Outputs (checkpoint, metrics JSON, loss curves and prediction plots) are written to `artifacts/`.

# %%
# Train the LSTM digital twin.
# On Colab: upload digital_twin_lstm.py and data/im_no_load_run1.csv first, then
#   !pip install -q torch scikit-learn pandas matplotlib
# %run ../digital_twin_lstm.py --csv ../data/im_no_load_run1.csv --output-dir ../artifacts
